# %%
import pandas as pd
import numpy as np
data = pd.read_csv("https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv")
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ### Features

# %%
data = data[['Make',
'Model',
'Year',
'Engine HP',
'Engine Cylinders',
'Transmission Type',
'Vehicle Style',
'highway MPG',
'city mpg',
'MSRP']]

# %% [markdown]
# ### Data preparation

# %%
data.columns = data.columns.str.replace(' ', '_').str.lower()

# %%
data.fillna(0, inplace=True)
# Out:
# C:\Users\omer_\AppData\Local\Temp\ipykernel_30572\2227532753.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.fillna(0, inplace=True)

# %%
data.isnull().sum()
# Out:
# make                 0
# model                0
# year                 0
# engine_hp            0
# engine_cylinders     0
# transmission_type    0
# vehicle_style        0
# highway_mpg          0
# city_mpg             0
# msrp                 0
# dtype: int64

# %%
data.rename(columns= {'msrp':'price'})
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  price
# 0                MANUAL          Coupe           26        19  46135
# 1                MANUAL    Convertible           28        19  40650
# ...

# %% [markdown]
# ## Question 1

# %%
data.value_counts('transmission_type')
# Out:
# transmission_type
# AUTOMATIC           8266
# MANUAL              2935
# AUTOMATED_MANUAL     626
# DIRECT_DRIVE          68
# UNKNOWN               19
# dtype: int64

# %% [markdown]
# ## Question 2

# %%
data.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# msrp                   int64
# dtype: object

# %%
numerik = [
    'year',
    'engine_hp',
    'engine_cylinders',
    'highway_mpg',
    'city_mpg',
]
kategorik = [
    'make',
    'model',
    'transmission_type',
    'vehicle_style'
]

# %%
data[numerik].corr()
# Out:
#                       year  engine_hp  engine_cylinders  highway_mpg  city_mpg
# year              1.000000   0.338714         -0.040708     0.258240  0.198171
# engine_hp         0.338714   1.000000          0.774851    -0.415707 -0.424918
# engine_cylinders -0.040708   0.774851          1.000000    -0.614541 -0.587306
# highway_mpg       0.258240  -0.415707         -0.614541     1.000000  0.886829
# city_mpg          0.198171  -0.424918         -0.587306     0.886829  1.000000

# %%
corr_mat = data[numerik].corr()
upper_corr_mat = corr_mat.where(np.triu(np.ones(corr_mat.shape), k=1).astype(np.bool_))

unique_corr_pairs = upper_corr_mat.unstack().dropna()

sorted_mat = unique_corr_pairs.sort_values()
sorted_mat
# Out:
# highway_mpg       engine_cylinders   -0.614541
# city_mpg          engine_cylinders   -0.587306
#                   engine_hp          -0.424918
# highway_mpg       engine_hp          -0.415707
# engine_cylinders  year               -0.040708
# city_mpg          year                0.198171
# highway_mpg       year                0.258240
# engine_hp         year                0.338714
# engine_cylinders  engine_hp           0.774851
# city_mpg          highway_mpg         0.886829
# dtype: float64

# %%
from sklearn.model_selection import train_test_split

full_train, data_test = train_test_split(data, test_size=0.2, random_state=42)
data_train, data_val = train_test_split(full_train, test_size=0.20, random_state=42)


data_train.reset_index(drop=True, inplace=True)
data_test.reset_index(drop=True, inplace=True)
data_val.reset_index(drop=True, inplace=True)


y_train = data_train['msrp'].values
y_test = data_test['msrp'].values
y_val = data_val['msrp'].values


del data_train['msrp']
del data_test['msrp']
del data_val['msrp']

# %%
y_train_num = y_train.copy()
y_val_num = y_val.copy()
y_test_num = y_test.copy()

y_train = (y_train > y_train.mean()).astype(int)
y_val = (y_val > y_val.mean()).astype(int)
y_tes = (y_test > y_test.mean()).astype(int)

# %%
data['msrp'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        46135
# 1        40650
# 2        36350
# 3        29450
# 4        34500
#          ...
# 11909    46120
# 11910    56670
# 11911    50620
# 11912    50920
# 11913    28995
# Name: msrp, Length: 11914, dtype: int64>

# %%
above_average = data['msrp'].apply(lambda x: 1 if data['msrp'].mean() < x else 0)

# %%
from sklearn.metrics import mutual_info_score

for bam in kategorik:
    data[bam]
    print(bam)
    monster_score = mutual_info_score(above_average, data[bam])
    print(round(monster_score,3))
# Out:
# make
# 0.238
# model
# 0.457
# transmission_type
# 0.02
# vehicle_style
# 0.083

# %% [markdown]
# #### Answer is transmission_type

# %% [markdown]
# # Question 4

# %%
from sklearn.feature_extraction import DictVectorizer

train_dicts = data_train[kategorik + numerik].to_dict(orient='records')

dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(train_dicts)

val_dicts = data_val[kategorik + numerik].to_dict(orient='records')
X_val = dv.transform(val_dicts)

test_dicts = data_test[kategorik + numerik].to_dict(orient='records')
X_test = dv.transform(test_dicts)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver="liblinear", C=1.0, max_iter=1000, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_val, model.predict(X_val))
round(acc, 2)
# Out:
# 0.93
